# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
import json
import numpy as np

# %%
csv_tickets_1 = "Resources/Parking_Tickets_1.csv"
ticket_df_1 = pd.read_csv(csv_tickets_1)
ticket_df_1.head()
# Out:
#   tag_number_masked  date_of_infraction  infraction_code  \
# 0          ***87325            20170101               15
# 1          ***87326            20170101               15
# 2          ***09493            20170101                3
# 3          ***67358            20170101                5
# 4          ***87327            20170101                5
#
#            infraction_description  set_fine_amount  time_of_infraction  \
# 0  PARK-WITHIN 3M OF FIRE HYDRANT              100                 1.0
# 1  PARK-WITHIN 3M OF FIRE HYDRANT              100                 1.0
# 2        PARK ON PRIVATE PROPERTY               30                 2.0
# 3  PARK-SIGNED HWY-PROHIBIT DY/TM               40                 3.0
# 4  PARK-SIGNED HWY-PROHIBIT DY/TM               40                 3.0
#
#   location1      location2 location3
# 0       OPP  11 CENTRE AVE       NaN
# 1       OPP  11 CENTRE AVE       NaN
# 2        NR   2425 JANE ST       NaN
# 3       N/S      DUNDAS SQ       E/O
# ...

# %%
csv_tickets_2 = "Resources/Parking_Tickets_2.csv"
ticket_df_2 = pd.read_csv(csv_tickets_2)
ticket_df_2.head()
# Out:
#   tag_number_masked  date_of_infraction  infraction_code  \
# 0          ***26271            20170510               29
# 1          ***47587            20170510               29
# 2          ***95886            20170510                3
# 3          ***60513            20170510                2
# 4          ***00993            20170510                8
#
#            infraction_description  set_fine_amount  time_of_infraction  \
# 0  PARK PROHIBITED TIME NO PERMIT               30               219.0
# 1  PARK PROHIBITED TIME NO PERMIT               30               219.0
# 2        PARK ON PRIVATE PROPERTY               30               220.0
# 3     PARK - LONGER THAN 3 HOURS                15               220.0
# 4    STAND VEH.-PROHIBIT TIME/DAY               60               220.0
#
#   location1          location2
# 0        NR    21 CLAXTON BLVD
# 1        NR   209 FAIRVIEW AVE
# 2        AT     24 MABELLE AVE
# 3        NR      18 LINDEN AVE
# 4        NR  364 ADELAIDE ST W

# %%
csv_tickets_3 = "Resources/Parking_Tickets_3.csv"
ticket_df_3 = pd.read_csv(csv_tickets_3)
ticket_df_3.head()
# Out:
#   tag_number_masked  date_of_infraction  infraction_code  \
# 0          ***98714            20170911              210
# 1          ***03276            20170911              403
# 2          ***06931            20170911                2
# 3          ***78878            20170911               29
# 4          ***01730            20170911              210
#
#            infraction_description  set_fine_amount  time_of_infraction  \
# 0    PARK FAIL TO DISPLAY RECEIPT               30              1707.0
# 1   STOP-SIGNED HIGHWAY-RUSH HOUR              150              1707.0
# 2     PARK - LONGER THAN 3 HOURS                15              1707.0
# 3  PARK PROHIBITED TIME NO PERMIT               30              1707.0
# 4    PARK FAIL TO DISPLAY RECEIPT               30              1707.0
#
#   location1           location2
# 0        NR  151 DAN LECKIE WAY
# 1        NR   2143 DANFORTH AVE
# 2        NR      90 BURNSIDE DR
# 3        NR        41 DALTON RD
# ...

# %%
tickets_2017_df=pd.concat([ticket_df_1,ticket_df_2,ticket_df_3])
locations = list(tickets_2017_df["location2"])
locations
# Out:
# C:\Users\jobag\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
# ['11 CENTRE AVE',
#  '11 CENTRE AVE',
#  '2425 JANE ST',
#  'DUNDAS SQ',
#  'ARMOURY ST',
#  '46 SPADINA AVE',
#  '39 LAKEVIEW AVE',
#  'ARMOURY ST',
#  'ARMOURY ST',
#  'FENWICK AVE',
#  '46 SPADINA AVE',
#  '21 CAMBRIDGE AVE',
#  'ARMOURY ST',
#  'ARMOURY ST',
#  'FENWICK AVE',
#  '40 HIGH PARK AVE',
#  'ARMOURY ST',
#  'FENWICK AVE',
#  'FENWICK AVE',
#  '46 SPADINA AVE',
#  '30 KINGSWOOD RD',
#  '27 CAMBRIDGE AVE',
#  '145 STRATHMORE BLVD',
#  'ARMOURY ST',
#  'FENWICK AVE',
#  'KINGSWOOD RD',
#  'KINGSWOOD RD',
#  '49 CAMBRIDGE AVE',
#  '2 CAITHNESS AVE',
#  '19 MACEY AVE',
#  '10 YUKON PLACE',
# ...

# %%
tickets_2017_df.head()
# Out:
#    date_of_infraction  infraction_code          infraction_description  \
# 0            20170101               15  PARK-WITHIN 3M OF FIRE HYDRANT
# 1            20170101               15  PARK-WITHIN 3M OF FIRE HYDRANT
# 2            20170101                3        PARK ON PRIVATE PROPERTY
# 3            20170101                5  PARK-SIGNED HWY-PROHIBIT DY/TM
# 4            20170101                5  PARK-SIGNED HWY-PROHIBIT DY/TM
#
#   location1      location2 location3  set_fine_amount tag_number_masked  \
# 0       OPP  11 CENTRE AVE       NaN              100          ***87325
# 1       OPP  11 CENTRE AVE       NaN              100          ***87326
# 2        NR   2425 JANE ST       NaN               30          ***09493
# 3       N/S      DUNDAS SQ       E/O               40          ***67358
# 4       N/S     ARMOURY ST       W/O               40          ***87327
#
#    time_of_infraction
# 0                 1.0
# 1                 1.0
# 2                 2.0
# ...

# %%
#Create SQL connection
engine = create_engine(f'mysql://{rds_connection_string}')

# %%
tickets_2017_df.to_sql(name='parking_tickets', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     582                                 (self.host, self.port), self.connect_timeout,
# --> 583                                 **kwargs)
#     584                             break
#
# ~\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# ~\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# ...
